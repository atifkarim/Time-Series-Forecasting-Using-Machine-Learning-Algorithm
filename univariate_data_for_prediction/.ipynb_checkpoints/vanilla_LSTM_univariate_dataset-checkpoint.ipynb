# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import time
import datetime
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
test=pd.read_csv('E:/University of Bremen MSc/masters_thesis/IAT_sebastian/dataset_26_april_3.csv')

# %%
longTime=test.loc[0:,['longTime']]
longTime=longTime.as_matrix()
a=[]
date_time_array=[]
for k in longTime:
    a=np.append(a,k)
str_time=[]
correct_longtime=[]
datetime_time=[]
count=0
for b in a:
    b=int(b) # make plain integer
    str_b=str(b)
    c=str_b[-3:]
    new_str_b=str_b.replace(c, '',1)
    new_str_b_time=int(new_str_b)
    correct_longtime.append(new_str_b_time)
    now_time=datetime.datetime.fromtimestamp(new_str_b_time)
    convert_time=now_time.strftime('%Y-%m-%d %H:%M')
    str_time.append(convert_time)
# print(str_time)
test_new = test.assign(stringTime=str_time,correct_longtime=correct_longtime) # here new column in the panda dataframe for string_time has added
# Out:
# C:\Users\atif\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
test_new['dateTime'] =  pd.to_datetime(test_new['stringTime'], format='%Y-%m-%d %H:%M')

# %%
test_new.shape #ROWS, COLUMNS
# Out:
# (25000, 4223)

# %%
test_new = test_new.set_index('dateTime') # make dataTime column as index of the dataframe test_new

# %%
univariate_column_label=['DEWIHOBT9_I0','AEDAHO_T9_V2','AEWIHO_T9AV2','RWWIHOB_MWT0']

# %%
size_column = len(univariate_column_label)
print(size_column)
# Out:
# 4

# %%
univariate_data=test_new.iloc[2000:7000][univariate_column_label]
univariate_data=univariate_data.loc[::-1]
print(univariate_data.head())
# Out:
#                      DEWIHOBT9_I0  AEDAHO_T9_V2  AEWIHO_T9AV2  RWWIHOB_MWT0
# dateTime
# 2019-04-06 00:21:00         100.0     72.427071     76.598087     95.920205
# 2019-04-06 00:22:00         100.0     71.620643     76.358689     95.839281
# 2019-04-06 00:23:00         100.0     70.606738     77.241097     95.820845
# 2019-04-06 00:24:00         100.0     70.531626     77.062413     95.668621
# 2019-04-06 00:25:00         100.0     70.692115     76.297974     95.543627

# %%
ax = univariate_data.plot(subplots=True, layout=(size_column,1))
plt.rcParams['figure.figsize'] =(20,10)
# plt.savefig('E:/University of Bremen MSc/masters_thesis/forecasting_sensor_data_Salzgitter_AG/images_from_training/multivariate_data_regression.png')
# plt.rcParams['figure.figsize'] =(20,10)
plt.show()

# %%
zero_index=[]
zero_index=np.array(zero_index)
for index, value in univariate_data.iterrows():
    for i , v in enumerate(value):
        if i == 0  and v == 0.0:
#             print('index: ',index)
            zero_index=np.append(zero_index,index)

print('size of zero_index: ',zero_index.size)
# Out:
# size of zero_index:  0

# %%
if zero_index.size > 0:
    univariate_data_modify = univariate_data.drop(zero_index,axis=0) # axis= 0 means row indiated. 1 means column indicated
else:
    univariate_data_modify = univariate_data

# %%
bx = univariate_data_modify.plot(subplots=True, layout=(size_column,1))
plt.rcParams['figure.figsize'] =(20,10)
plt.show()

# %%
univariate_data_1= univariate_data_modify.drop(['DEWIHOBT9_I0','AEWIHO_T9AV2','RWWIHOB_MWT0'], axis=1)
univariate_data_2= univariate_data_modify.drop(['DEWIHOBT9_I0','AEDAHO_T9_V2','RWWIHOB_MWT0'], axis=1)
univariate_data_3= univariate_data_modify.drop(['DEWIHOBT9_I0','AEWIHO_T9AV2','AEDAHO_T9_V2'], axis=1)

# %%
print('univariate_data_1 head: \n',univariate_data_1.head())
print('univariate_data_2 head: \n',univariate_data_2.head())
print('univariate_data_3 head: \n',univariate_data_3.head())
# Out:
# univariate_data_1 head:
#                       AEDAHO_T9_V2
# dateTime
# 2019-04-06 00:21:00     72.427071
# 2019-04-06 00:22:00     71.620643
# 2019-04-06 00:23:00     70.606738
# 2019-04-06 00:24:00     70.531626
# 2019-04-06 00:25:00     70.692115
# univariate_data_2 head:
#                       AEWIHO_T9AV2
# dateTime
# 2019-04-06 00:21:00     76.598087
# 2019-04-06 00:22:00     76.358689
# 2019-04-06 00:23:00     77.241097
# 2019-04-06 00:24:00     77.062413
# 2019-04-06 00:25:00     76.297974
# univariate_data_3 head:
#                       RWWIHOB_MWT0
# dateTime
# 2019-04-06 00:21:00     95.920205
# 2019-04-06 00:22:00     95.839281
# 2019-04-06 00:23:00     95.820845
# 2019-04-06 00:24:00     95.668621
# 2019-04-06 00:25:00     95.543627

# %%
# for col in univariate_data_1.columns:
#     print(col)

# %% [markdown]
# # Replace zero'0' value with NAN and then drop those rows

# %%
from numpy import nan
univariate_data_drop_zero_1 = univariate_data_1.replace(0,nan)
univariate_data_drop_zero_1 = univariate_data_drop_zero_1.dropna(how='any',axis=0)

univariate_data_drop_zero_2 = univariate_data_2.replace(0,nan)
univariate_data_drop_zero_2 = univariate_data_drop_zero_2.dropna(how='any',axis=0)

univariate_data_drop_zero_3 = univariate_data_3.replace(0,nan)
univariate_data_drop_zero_3 = univariate_data_drop_zero_3.dropna(how='any',axis=0)

# %%
cx = univariate_data_drop_zero_1.plot()
dx = univariate_data_drop_zero_2.plot()
ex = univariate_data_drop_zero_3.plot()
# plt.legend(loc='upper left')
plt.rcParams['figure.figsize'] =(20,10)
plt.show()

# %% [markdown]
# # Function for making dataset for feeding in the MODEL. Just change the argument for working with the another dataframe
# ##here, 2 dataframe has used and they are
# ##univariate_data_drop_zero_1
# ##univariate_data_drop_zero_2

# %%
def make_dataset(PandaDataframe):
    dataset = np.array(PandaDataframe)

    NumberOfElements = int(len(dataset)*0.9)
    print('dataset length: ',len(dataset))
    print('Number of Elements for training: ',NumberOfElements)

    train_data = dataset[0:NumberOfElements]
    test_data = dataset[NumberOfElements:len(dataset)]
    
    return train_data, test_data

# train_data_vanilla, test_data_vanilla = make_dataset(univariate_data_drop_zero_1)
train_data_vanilla, test_data_vanilla = make_dataset(univariate_data_drop_zero_2)
# train_data_vanilla, test_data_vanilla = make_dataset(univariate_data_drop_zero_3)
print('train_data_vanilla shape: ', train_data_vanilla.shape)
print('test_data_vanilla shape: ', test_data_vanilla.shape)
# Out:
# dataset length:  4999
# Number of Elements for training:  4499
# train_data_vanilla shape:  (4499, 1)
# test_data_vanilla shape:  (500, 1)

# %%
print(train_data_vanilla, '\nprinting for lstm',X_train_vanilla)
# Out:
# [[76.59808733]
#  [76.35868881]
#  [77.24109727]
#  ...
#  [70.15414622]
#  [70.16358374]
#  [70.14376494]]
# printing for lstm [[[76.59808733]]
#
#  [[76.35868881]]
#
#  [[77.24109727]]
#
#  ...
#
#  [[70.26928401]]
#
#  [[70.15414622]]
#
#  [[70.16358374]]]

# %% [markdown]
# # function for making train and test dataset suitable for VANILLA LSTM

# %%
from numpy import array
 
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    print(len(sequence))
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
#         print(end_ix)
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
# choose a number of time steps
n_steps = 1
# split into samples
X_train_vanilla, y_train_vanilla = split_sequence(train_data_vanilla, n_steps)
# print(X.shape,'\t',X.ndim,'\t',X.size)
# print(y.shape,'\t',y.ndim,'\t',y.size)
print(X_train_vanilla.shape,'\t',X_train_vanilla.ndim,'\t',X_train_vanilla.size)
print(y_train_vanilla.shape,'\t',y_train_vanilla.ndim,'\t',y_train_vanilla.size)
# summarize the data
# for i in range(len(X)):
# 	print(X[i], y[i])
# Out:
# 4499
# (4498, 1, 1) 	 3 	 4498
# (4498, 1) 	 2 	 4498

# %%
n_features = X_train_vanilla.shape[-1]
X_train_vanilla = X_train_vanilla.reshape((X_train_vanilla.shape[0], X_train_vanilla.shape[1], n_features))

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
# Out:
# C:\Users\atif\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
lr = 0.01

def lr_schedule(epoch):
    return lr * (0.1 ** int(epoch / 10))

batch_size=32
epochs=30

# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse',metrics=['accuracy'])

print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a8aca45408f4> in <module>()
#       9
#      10 # define model
# ---> 11 model = Sequential()
#      12 model.add(input_shape=(n_steps, n_feature))
#      13 model.add(LSTM(50, activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
# fit model
train_model=model.fit(X_train_vanilla, y_train_vanilla, batch_size=batch_size, epochs=epochs,verbose=5,
          callbacks=[LearningRateScheduler(lr_schedule),
                     ModelCheckpoint('/media/atif/BE0E05910E0543BD/University of Bremen MSc/masters_thesis/forecasting_sensor_data_Salzgitter_AG/trained_model_file/vanilla_100.h5', save_best_only=True)])
# Out:
# Epoch 1/30
# C:\Users\atif\Anaconda3\lib\site-packages\keras\callbacks.py:434: RuntimeWarning: Can save best model only with val_loss available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# Epoch 2/30
# Epoch 3/30
# Epoch 4/30
# Epoch 5/30
# Epoch 6/30
# Epoch 7/30
# Epoch 8/30
# Epoch 9/30
# Epoch 10/30
# Epoch 11/30
# Epoch 12/30
# Epoch 13/30
# Epoch 14/30
# Epoch 15/30
# Epoch 16/30
# Epoch 17/30
# Epoch 18/30
# Epoch 19/30
# Epoch 20/30
# Epoch 21/30
# Epoch 22/30
# Epoch 23/30
# Epoch 24/30
# Epoch 25/30
# Epoch 26/30
# Epoch 27/30
# Epoch 28/30
# Epoch 29/30
# Epoch 30/30

# %%
test_ip_vanilla,test_op_vanilla=split_sequence(test_data_vanilla,n_steps)
n_features_test = test_ip_vanilla.shape[-1]
X_test_ip_vanilla=test_ip_vanilla.reshape((test_ip_vanilla.shape[0], test_ip_vanilla.shape[1], n_features_test))
# Out:
# 500

# %%
yhat = model.predict(X_test_ip_vanilla, verbose=1)
# Out:
# 499/499 [==============================] - 0s 214us/step

# %%
plt.plot(yhat[0:50],color='green',marker='s', linestyle=':')
plt.plot(test_op_vanilla[0:50],color='red',marker='^', linestyle=':')
plt.title('deviation between predicted and target value')
plt.ylabel('value')
plt.xlabel('range')
plt.legend(['yhat', 'test_op'], loc='upper left')
plt.grid(b=None, which='both', axis='both')
plt.xticks(np.arange(0,50,1))
plt.xticks( rotation=25)
plt.rcParams['figure.figsize'] =(20,10)
plt.show()

# %%
from sklearn.metrics import mean_squared_error

#Print MSE to see how good the model is
Error = mean_squared_error(test_op_vanilla,yhat)
print(Error)
# Out:
# 1.41518284374503

# %%
type(test_op_vanilla)
# Out:
# numpy.ndarray

# %% [markdown]
# # Do normalization

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
# min_max_scaler = preprocessing.MinMaxScaler()
# np_scaled = min_max_scaler.fit_transform(multivariate_data_drop_zero)

# df_normalized = pd.DataFrame(np_scaled,index=multivariate_data_drop_zero.index,columns=multivariate_column_label)


def make_dataset(PandaDataframe):
    
#     min_max_scaler = preprocessing.MinMaxScaler()
    global np_scaled
    np_scaled = min_max_scaler.fit_transform(PandaDataframe)
    global df_normalized
    df_normalized = pd.DataFrame(np_scaled,index=PandaDataframe.index,columns = PandaDataframe.columns)
    
    np_scaled_unnorm = min_max_scaler.inverse_transform(df_normalized)
    df_normalized_unnorm = pd.DataFrame(np_scaled_unnorm,index=PandaDataframe.index,columns = PandaDataframe.columns)
    print(PandaDataframe.head(), '\n')
    print(df_normalized.head(), '\n')
    print(df_normalized_unnorm.head())
#     dataset = df_normalized
    dataset = np.array(df_normalized)

    NumberOfElements = int(len(dataset)*0.9)
    print('dataset length: ',len(dataset))
    print('Number of Elements for training: ',NumberOfElements)

    train_data_norm = dataset[0:NumberOfElements]
    test_data_norm = dataset[NumberOfElements:len(dataset)]
    
    return train_data_norm, test_data_norm

train_data_vanilla_norm, test_data_vanilla_norm = make_dataset(univariate_data_drop_zero_1)
print('train_data_vanilla_norm shape: ', train_data_vanilla_norm.shape)
print('test_data_vanilla_norm shape: ', test_data_vanilla_norm.shape)
# Out:
#                      AEDAHO_T9_V2
# dateTime
# 2019-04-06 00:21:00     72.427071
# 2019-04-06 00:22:00     71.620643
# 2019-04-06 00:23:00     70.606738
# 2019-04-06 00:24:00     70.531626
# 2019-04-06 00:25:00     70.692115
#
#                      AEDAHO_T9_V2
# dateTime
# 2019-04-06 00:21:00      0.497921
# 2019-04-06 00:22:00      0.477305
# 2019-04-06 00:23:00      0.451385
# 2019-04-06 00:24:00      0.449465
# 2019-04-06 00:25:00      0.453568
#
#                      AEDAHO_T9_V2
# dateTime
# 2019-04-06 00:21:00     72.427071
# 2019-04-06 00:22:00     71.620643
# 2019-04-06 00:23:00     70.606738
# 2019-04-06 00:24:00     70.531626
# 2019-04-06 00:25:00     70.692115
# dataset length:  4999
# Number of Elements for training:  4499
# train_data_vanilla_norm shape:  (4499, 1)
# test_data_vanilla_norm shape:  (500, 1)

# %%
print(df_normalized.head())
# Out:
#                      AEDAHO_T9_V2
# dateTime
# 2019-04-06 00:21:00      0.497921
# 2019-04-06 00:22:00      0.477305
# 2019-04-06 00:23:00      0.451385
# 2019-04-06 00:24:00      0.449465
# 2019-04-06 00:25:00      0.453568

# %%
np_scaled_unnorm = min_max_scaler.inverse_transform(df_normalized)
# global df_normalized
df_normalized_unnorm_1 = pd.DataFrame(np_scaled_unnorm,index=univariate_data_drop_zero_1.index,columns = univariate_data_drop_zero_1.columns)

# %%
df_normalized_unnorm_1.head()
# Out:
#                      AEDAHO_T9_V2
# dateTime
# 2019-04-06 00:21:00     72.427071
# 2019-04-06 00:22:00     71.620643
# 2019-04-06 00:23:00     70.606738
# 2019-04-06 00:24:00     70.531626
# 2019-04-06 00:25:00     70.692115

# %%
# choose a number of time steps
n_steps = 1
# split into samples
X_train_vanilla_norm, y_train_vanilla_norm = split_sequence(train_data_vanilla_norm, n_steps)
# print(X.shape,'\t',X.ndim,'\t',X.size)
# print(y.shape,'\t',y.ndim,'\t',y.size)
print(X_train_vanilla_norm.shape,'\t',X_train_vanilla_norm.ndim,'\t',X_train_vanilla_norm.size)
print(y_train_vanilla_norm.shape,'\t',y_train_vanilla_norm.ndim,'\t',y_train_vanilla_norm.size)
# summarize the data
# for i in range(len(X)):
# 	print(X[i], y[i])
# Out:
# 4499
# (4498, 1, 1) 	 3 	 4498
# (4498, 1) 	 2 	 4498

# %%
n_features = X_train_vanilla_norm.shape[-1]
X_train_vanilla_norm = X_train_vanilla_norm.reshape((X_train_vanilla_norm.shape[0], X_train_vanilla_norm.shape[1], n_features))

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
# Out:
# C:\Users\atif\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
lr = 0.01

def lr_schedule(epoch):
    return lr * (0.1 ** int(epoch / 10))

batch_size=32
epochs=30

# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse',metrics=['accuracy'])
# fit model
train_model=model.fit(X_train_vanilla_norm, y_train_vanilla_norm, batch_size=batch_size, epochs=epochs,verbose=1,
          callbacks=[LearningRateScheduler(lr_schedule),
                     ModelCheckpoint('/media/atif/BE0E05910E0543BD/University of Bremen MSc/masters_thesis/forecasting_sensor_data_Salzgitter_AG/trained_model_file/vanilla_100.h5', save_best_only=True)])
# Out:
# Epoch 1/30
# 4498/4498 [==============================] - 1s 310us/step - loss: 0.0178 - acc: 2.2232e-04
# Epoch 2/30
# 1952/4498 [============>.................] - ETA: 0s - loss: 0.0018 - acc: 5.1230e-04
# C:\Users\atif\Anaconda3\lib\site-packages\keras\callbacks.py:434: RuntimeWarning: Can save best model only with val_loss available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 4498/4498 [==============================] - 0s 76us/step - loss: 0.0016 - acc: 2.2232e-04
# Epoch 3/30
# 4498/4498 [==============================] - 0s 91us/step - loss: 0.0014 - acc: 2.2232e-04
# Epoch 4/30
# 4498/4498 [==============================] - 0s 88us/step - loss: 0.0014 - acc: 2.2232e-04
# Epoch 5/30
# 4498/4498 [==============================] - 0s 74us/step - loss: 0.0013 - acc: 2.2232e-04
# Epoch 6/30
# 4498/4498 [==============================] - 0s 104us/step - loss: 0.0013 - acc: 2.2232e-04
# Epoch 7/30
# 4498/4498 [==============================] - 0s 102us/step - loss: 0.0013 - acc: 2.2232e-04
# Epoch 8/30
# 4498/4498 [==============================] - 0s 107us/step - loss: 0.0013 - acc: 2.2232e-04
# Epoch 9/30
# 4498/4498 [==============================] - 0s 95us/step - loss: 0.0013 - acc: 2.2232e-04
# Epoch 10/30
# 4498/4498 [==============================] - ETA: 0s - loss: 0.0013 - acc: 2.3674e-0 - 0s 65us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 11/30
# 4498/4498 [==============================] - 0s 91us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 12/30
# 4498/4498 [==============================] - 0s 61us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 13/30
# 4498/4498 [==============================] - 0s 95us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 14/30
# 4498/4498 [==============================] - 0s 63us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 15/30
# 4498/4498 [==============================] - 0s 61us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 16/30
# 4498/4498 [==============================] - 0s 61us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 17/30
# 4498/4498 [==============================] - 0s 72us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 18/30
# 4498/4498 [==============================] - 0s 66us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 19/30
# 4498/4498 [==============================] - 0s 63us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 20/30
# 4498/4498 [==============================] - 0s 61us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 21/30
# 4498/4498 [==============================] - 0s 60us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 22/30
# 4498/4498 [==============================] - 0s 63us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 23/30
# 4498/4498 [==============================] - 0s 68us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 24/30
# 4498/4498 [==============================] - 0s 64us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 25/30
# 4498/4498 [==============================] - 0s 90us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 26/30
# 4498/4498 [==============================] - 0s 104us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 27/30
# 4498/4498 [==============================] - 0s 92us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 28/30
# 4498/4498 [==============================] - 0s 84us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 29/30
# 4498/4498 [==============================] - 0s 91us/step - loss: 0.0012 - acc: 2.2232e-04
# Epoch 30/30
# 4498/4498 [==============================] - 0s 67us/step - loss: 0.0012 - acc: 2.2232e-04

# %%
test_ip_vanilla_norm,test_op_vanilla_norm=split_sequence(test_data_vanilla_norm,n_steps)
n_features_test = test_ip_vanilla_norm.shape[-1]
X_test_ip_vanilla_norm = test_ip_vanilla_norm.reshape((test_ip_vanilla_norm.shape[0], test_ip_vanilla_norm.shape[1], n_features_test))
# Out:
# 500

# %%
yhat_norm = model.predict(X_test_ip_vanilla, verbose=1)
# Out:
# 499/499 [==============================] - 0s 32us/step

# %%
yhat_norm
# Out:
# array([[65.2656  ],
#        [66.729904],
#        [65.65516 ],
#        [62.754375],
#        [61.016804],
#        [61.19405 ],
#        [60.652493],
#        [60.20093 ],
#        [60.44344 ],
#        [60.05769 ],
#        [60.087593],
#        [59.832928],
#        [59.64271 ],
#        [59.639984],
#        [59.872395],
#        [59.301754],
#        [59.32291 ],
#        [59.464382],
#        [59.36525 ],
#        [59.310356],
#        [59.14349 ],
#        [59.23798 ],
#        [58.932114],
#        [59.297382],
#        [59.277996],
#        [59.362926],
#        [59.289867],
#        [59.4977  ],
#        [59.21996 ],
#        [59.112225],
#        [59.352413],
#        [60.98581 ],
#        [64.34664 ],
#        [65.646965],
#        [65.8298  ],
#        [63.087826],
#        [60.463104],
#        [59.971252],
#        [59.570614],
#        [59.38041 ],
#        [58.537617],
#        [58.78573 ],
#        [58.73316 ],
#        [58.738888],
#        [58.744495],
#        [58.894703],
#        [58.98373 ],
#        [58.808254],
#        [58.781086],
#        [58.668022],
#        [58.45036 ],
#        [58.65205 ],
#        [59.256824],
#        [58.872707],
#        [58.596745],
#        [58.649723],
#        [59.03029 ],
#        [59.215176],
#        [59.22187 ],
#        [59.446083],
#        [59.139122],
#        [58.919415],
#        [59.205074],
#        [59.09734 ],
#        [61.298496],
#        [63.973194],
#        [65.10379 ],
#        [65.02241 ],
#        [63.781483],
#        [60.366154],
#        [59.01691 ],
#        [58.708035],
#        [59.28195 ],
#        [58.99233 ],
#        [58.899067],
#        [58.910404],
#        [58.757603],
#        [59.036297],
#        [59.084362],
#        [58.88391 ],
#        [58.661198],
#        [58.575993],
#        [58.884724],
#        [58.882412],
#        [58.253582],
#        [58.35751 ],
#        [58.40653 ],
#        [58.66024 ],
#        [58.986183],
#        [58.961742],
#        [58.844856],
#        [58.68168 ],
#        [58.933613],
#        [59.073166],
#        [59.011173],
#        [59.200157],
#        [59.476948],
#        [63.68508 ],
#        [65.063644],
#        [65.609695],
#        [64.26868 ],
#        [61.086308],
#        [59.61527 ],
#        [59.798107],
#        [59.426014],
#        [58.91914 ],
#        [59.22528 ],
#        [59.05596 ],
#        [58.7292  ],
#        [58.995335],
#        [59.28113 ],
#        [59.254093],
#        [59.474487],
#        [59.312267],
#        [59.528835],
#        [59.37631 ],
#        [59.382587],
#        [59.313084],
#        [59.372623],
#        [59.321545],
#        [59.133114],
#        [59.208763],
#        [59.060604],
#        [59.459057],
#        [59.852726],
#        [59.95254 ],
#        [59.84686 ],
#        [59.918133],
#        [59.99515 ],
#        [62.97463 ],
#        [65.07976 ],
#        [66.123924],
#        [64.935295],
#        [62.305   ],
#        [60.177853],
#        [59.66811 ],
#        [59.151955],
#        [58.968025],
#        [59.034794],
#        [58.98318 ],
#        [59.026333],
#        [59.033833],
#        [58.65546 ],
#        [58.309673],
#        [58.208164],
#        [57.99306 ],
#        [57.624302],
#        [57.786938],
#        [57.743725],
#        [57.57867 ],
#        [58.096783],
#        [58.08902 ],
#        [57.68667 ],
#        [57.51785 ],
#        [57.53229 ],
#        [57.772327],
#        [57.909313],
#        [58.15392 ],
#        [58.196274],
#        [58.168697],
#        [58.224167],
#        [58.065105],
#        [61.40269 ],
#        [63.823402],
#        [64.676674],
#        [63.958447],
#        [60.427597],
#        [59.067844],
#        [58.6582  ],
#        [57.83595 ],
#        [58.525745],
#        [57.90353 ],
#        [58.02748 ],
#        [57.785267],
#        [57.927284],
#        [57.615932],
#        [58.07226 ],
#        [58.373898],
#        [58.191402],
#        [58.23788 ],
#        [58.48573 ],
#        [58.622272],
#        [58.22066 ],
#        [57.788006],
#        [57.42358 ],
#        [57.45171 ],
#        [57.2821  ],
#        [57.25156 ],
#        [57.38999 ],
#        [57.686974],
#        [57.26022 ],
#        [57.62749 ],
#        [57.613804],
#        [56.79264 ],
#        [56.987026],
#        [57.057777],
#        [56.93755 ],
#        [56.899155],
#        [57.616394],
#        [57.585976],
#        [57.447906],
#        [60.39223 ],
#        [62.87686 ],
#        [63.88061 ],
#        [62.65729 ],
#        [60.315628],
#        [58.926235],
#        [58.39684 ],
#        [58.40994 ],
#        [58.514538],
#        [58.53967 ],
#        [58.37663 ],
#        [58.4464  ],
#        [58.46088 ],
#        [58.361607],
#        [58.66065 ],
#        [58.640438],
#        [58.36079 ],
#        [58.22797 ],
#        [58.288025],
#        [58.360374],
#        [58.324917],
#        [58.3487  ],
#        [58.33879 ],
#        [58.346867],
#        [58.194904],
#        [58.22569 ],
#        [57.645893],
#        [57.519062],
#        [57.424805],
#        [59.631107],
#        [62.68774 ],
#        [63.715256],
#        [63.12565 ],
#        [60.916172],
#        [58.871346],
#        [58.323853],
#        [58.160168],
#        [57.965046],
#        [57.31127 ],
#        [57.335888],
#        [57.477856],
#        [58.053524],
#        [57.626118],
#        [57.54582 ],
#        [57.472683],
#        [58.316227],
#        [58.21807 ],
#        [58.15575 ],
#        [58.1719  ],
#        [58.114002],
#        [58.00068 ],
#        [58.019108],
#        [57.91373 ],
#        [58.03555 ],
#        [57.52423 ],
#        [57.37206 ],
#        [57.20949 ],
#        [57.429058],
#        [58.10136 ],
#        [57.66141 ],
#        [57.276173],
#        [58.0019  ],
#        [57.430275],
#        [57.525288],
#        [57.52438 ],
#        [57.629013],
#        [59.754818],
#        [64.01416 ],
#        [64.61919 ],
#        [63.76373 ],
#        [60.101517],
#        [59.415222],
#        [58.95396 ],
#        [58.403797],
#        [58.19019 ],
#        [58.130306],
#        [57.587193],
#        [57.88496 ],
#        [57.27496 ],
#        [57.53397 ],
#        [57.453228],
#        [57.62521 ],
#        [57.312946],
#        [57.014965],
#        [57.18989 ],
#        [56.99947 ],
#        [57.132477],
#        [56.938305],
#        [57.151314],
#        [56.97595 ],
#        [57.29623 ],
#        [57.81205 ],
#        [57.35048 ],
#        [57.286053],
#        [57.330875],
#        [57.534267],
#        [56.526684],
#        [57.095882],
#        [57.052307],
#        [57.43453 ],
#        [57.34531 ],
#        [57.386803],
#        [57.87766 ],
#        [57.986366],
#        [58.311043],
#        [57.782528],
#        [57.70264 ],
#        [58.00845 ],
#        [60.696053],
#        [64.5744  ],
#        [65.44857 ],
#        [64.260216],
#        [60.90511 ],
#        [59.02442 ],
#        [58.212887],
#        [58.084293],
#        [57.679966],
#        [57.502636],
#        [57.36233 ],
#        [57.564373],
#        [57.39136 ],
#        [57.934597],
#        [57.84843 ],
#        [58.34839 ],
#        [58.856052],
#        [58.113544],
#        [57.72166 ],
#        [57.36735 ],
#        [57.327084],
#        [57.36842 ],
#        [57.322216],
#        [57.162395],
#        [57.0517  ],
#        [57.41158 ],
#        [57.61076 ],
#        [57.306713],
#        [57.727444],
#        [58.24367 ],
#        [58.225082],
#        [58.39847 ],
#        [58.13579 ],
#        [57.640575],
#        [58.096634],
#        [57.931698],
#        [57.5665  ],
#        [57.401546],
#        [57.687893],
#        [57.803833],
#        [58.557827],
#        [58.4408  ],
#        [58.073635],
#        [58.381138],
#        [58.991375],
#        [58.578445],
#        [57.87826 ],
#        [61.26273 ],
#        [64.13978 ],
#        [64.20559 ],
#        [61.973057],
#        [59.28441 ],
#        [59.271572],
#        [58.291687],
#        [58.47945 ],
#        [59.22897 ],
#        [59.07385 ],
#        [59.10526 ],
#        [59.023464],
#        [59.009396],
#        [58.7886  ],
#        [58.41158 ],
#        [58.143406],
#        [57.948605],
#        [57.76518 ],
#        [57.782223],
#        [57.008587],
#        [57.215405],
#        [57.064453],
#        [56.827236],
#        [57.422215],
#        [58.748043],
#        [58.2708  ],
#        [57.426777],
#        [57.28316 ],
#        [57.285442],
#        [57.079033],
#        [57.529705],
#        [57.310673],
#        [57.48911 ],
#        [57.3859  ],
#        [57.42192 ],
#        [57.40413 ],
#        [57.67024 ],
#        [57.47436 ],
#        [57.541874],
#        [57.94723 ],
#        [57.642094],
#        [57.007217],
#        [57.34911 ],
#        [57.19855 ],
#        [56.86092 ],
#        [56.58732 ],
#        [57.02407 ],
#        [61.574474],
#        [64.331215],
#        [64.52374 ],
#        [62.035313],
#        [59.42847 ],
#        [59.034527],
#        [58.618046],
#        [58.010273],
#        [57.700817],
#        [57.4473  ],
#        [57.13415 ],
#        [56.95091 ],
#        [57.60027 ],
#        [57.32465 ],
#        [56.63462 ],
#        [57.247005],
#        [56.482277],
#        [56.82739 ],
#        [56.627796],
#        [56.144978],
#        [57.004486],
#        [56.61385 ],
#        [56.931477],
#        [57.24336 ],
#        [57.698536],
#        [57.85132 ],
#        [57.816006],
#        [57.80292 ],
#        [57.979214],
#        [57.7985  ],
#        [57.594486],
#        [57.44289 ],
#        [57.398205],
#        [57.692295],
#        [57.292286],
#        [57.430584],
#        [57.34045 ],
#        [57.45749 ],
#        [56.93603 ],
#        [57.420094],
#        [57.219967],
#        [57.738243],
#        [57.632057],
#        [57.1741  ],
#        [57.390453],
#        [57.982246],
#        [58.407352],
#        [62.94145 ],
#        [65.05108 ],
#        [64.756004],
#        [62.780045],
#        [59.725185],
#        [59.043396],
#        [58.75897 ],
#        [58.74954 ],
#        [58.612446],
#        [57.979214],
#        [57.28651 ],
#        [56.88823 ],
#        [57.131725],
#        [56.512745],
#        [56.324566],
#        [56.333042],
#        [57.070835],
#        [57.0646  ],
#        [57.276936],
#        [57.428753],
#        [57.361576],
#        [57.3052  ],
#        [57.295322],
#        [57.44669 ],
#        [57.695797],
#        [58.168095],
#        [57.97951 ],
#        [57.95119 ],
#        [58.506897],
#        [58.273544],
#        [63.316677],
#        [62.836857],
#        [62.732117],
#        [62.10673 ],
#        [62.812138],
#        [63.019825],
#        [62.684193],
#        [62.79794 ],
#        [63.24171 ],
#        [62.573036],
#        [62.63381 ],
#        [63.145306],
#        [62.66576 ],
#        [62.295444],
#        [62.82688 ],
#        [64.316605],
#        [69.55485 ],
#        [72.622116],
#        [72.003456]], dtype=float32)

# %%
plt.plot(yhat_norm,color='green')
# plt.plot(test_op_vanilla_norm,color='red')
plt.plot(test_op_vanilla,color='black')
plt.xticks( rotation=25)
plt.title('deviation between predicted and target value')
plt.ylabel('value')
plt.xlabel('range')
# plt.legend(['yhat_norm', 'test_op_vanilla_norm'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

#Print MSE to see how good the model is
Error_norm = mean_squared_error(test_op_vanilla_norm,yhat_norm)
print(Error_norm)
# Out:
# 0.0008752261980417935

# %%
from sklearn.metrics import mean_squared_error

#Print MSE to see how good the model is
Error_norm = mean_squared_error(test_op_vanilla,yhat_norm)
print(Error_norm)
# Out:
# 13.511378289272857
