# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import time
import datetime
# %matplotlib inline
from matplotlib.pylab import rcParams

# %%
test= pd.read_csv('/media/atif/BE0E05910E0543BD/University of Bremen MSc/masters_thesis/IAT_sebastian/dataset_26_april_3.csv')

# %%
longTime=test.loc[0:,['longTime']]
longTime=longTime.as_matrix()
a=[]
date_time_array=[]
for k in longTime:
    a=np.append(a,k)
str_time=[]
correct_longtime=[]
datetime_time=[]
count=0
for b in a:
    b=int(b) # make plain integer
    str_b=str(b)
    c=str_b[-3:]
    new_str_b=str_b.replace(c, '',1)
    new_str_b_time=int(new_str_b)
    correct_longtime.append(new_str_b_time)
    now_time=datetime.datetime.fromtimestamp(new_str_b_time)
    convert_time=now_time.strftime('%Y-%m-%d %H:%M')
    str_time.append(convert_time)
# print(str_time)
test_new = test.assign(stringTime=str_time,correct_longtime=correct_longtime) # here new column in the panda dataframe for string_time has added
# Out:
# /home/atif/anaconda3/envs/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
test_new['dateTime'] =  pd.to_datetime(test_new['stringTime'], format='%Y-%m-%d %H:%M')

# %%
test_new.shape #ROWS, COLUMNS
# Out:
# (25000, 4223)

# %%
test_new = test_new.set_index('dateTime') # make dataTime column as index of the dataframe test_new

# %%
multivariate_column_label=['AEDATZ_HO_V0','AEWIHO_T9AV2','AEWIHOAVABV2','RWWIHOA_HWT0','AEWIHOAKZ_V0',
                           'RWWIHOA_MWT0','AEDAHO_T9_V2'] # choose column with which the following work will be conducted
univariate_column_label=['AEDAHO_T9_V2']
multivariate_data=test_new.iloc[500:20000][multivariate_column_label] #just for checking whether it is working or not
print(multivariate_data.head())
# Out:
#                      AEDATZ_HO_V0  AEWIHO_T9AV2  AEWIHOAVABV2  RWWIHOA_HWT0  \
# dateTime
# 2019-04-11 11:33:00     36.275050     64.671260     80.287128     91.094201
# 2019-04-11 11:32:00     34.384378     64.795520     80.112264     91.007505
# 2019-04-11 11:31:00     32.296527     64.542595     80.248003     91.087722
# 2019-04-11 11:30:00     30.584083     64.560526     80.273953     91.070699
# 2019-04-11 11:29:00     29.099978     64.576255     80.056771     91.314595
#
#                      AEWIHOAKZ_V0  RWWIHOA_MWT0  AEDAHO_T9_V2
# dateTime
# 2019-04-11 11:33:00           0.0     94.536148     42.305187
# 2019-04-11 11:32:00           0.0     94.486522     42.480315
# 2019-04-11 11:31:00           0.0     94.449906     42.343193
# 2019-04-11 11:30:00           0.0     94.516623     42.108748
# 2019-04-11 11:29:00           0.0     94.536962     42.292350

# %%
multivariate_data=multivariate_data.loc[::-1]
print(multivariate_data.head())
# Out:
#                      AEDATZ_HO_V0  AEWIHO_T9AV2  AEWIHOAVABV2  RWWIHOA_HWT0  \
# dateTime
# 2019-03-20 14:00:00     58.849192     82.164653     88.135228     92.213203
# 2019-03-20 14:01:00     59.596989     84.719391     88.256994     92.301521
# 2019-03-20 14:02:00     57.521160     85.343840     88.350813     92.459522
# 2019-03-20 14:03:00     55.506700     85.319617     88.098498     92.295853
# 2019-03-20 14:04:00     54.717202     84.241223     88.145209     92.287743
#
#                      AEWIHOAKZ_V0  RWWIHOA_MWT0  AEDAHO_T9_V2
# dateTime
# 2019-03-20 14:00:00     45.592339     89.399347     80.655537
# 2019-03-20 14:01:00     44.759943     89.539277     81.089756
# 2019-03-20 14:02:00     45.274554     89.598665     80.335200
# 2019-03-20 14:03:00     45.078444     89.410738     75.924448
# 2019-03-20 14:04:00     42.677696     89.359484     73.998452

# %%
multivariate_data.plot()
plt.rcParams['figure.figsize'] =(20,10)
plt.show()

# %%
# remove this line if you want do not want to count mean. Just comment it and uncomment the below lines.
multi_mean=multivariate_data.mean()
multivariate_data_mean= multivariate_data.replace(0,multi_mean)

# %%
multivariate_data_mean.plot()
plt.show()

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(multivariate_data_mean)
# col_label=['AEDATZ_HO_V0','AEWIHO_T9AV2','AEWIHOAVABV2','RWWIHOA_HWT0','AEWIHOAKZ_V0','RWWIHOA_MWT0','AEDAHO_T9_V2']
df_normalized = pd.DataFrame(np_scaled,index=multivariate_data.index,columns=multivariate_column_label)

# %%
np_unscaled=min_max_scaler.inverse_transform(np_scaled)
df_unnormalized=pd.DataFrame(np_unscaled,index=multivariate_data.index,columns=multivariate_column_label)

# %%
df_unnormalized.head()
# Out:
#                      AEDATZ_HO_V0  AEWIHO_T9AV2  AEWIHOAVABV2  RWWIHOA_HWT0  \
# dateTime
# 2019-03-20 14:00:00     58.849192     82.164653     88.135228     92.213203
# 2019-03-20 14:01:00     59.596989     84.719391     88.256994     92.301521
# 2019-03-20 14:02:00     57.521160     85.343840     88.350813     92.459522
# 2019-03-20 14:03:00     55.506700     85.319617     88.098498     92.295853
# 2019-03-20 14:04:00     54.717202     84.241223     88.145209     92.287743
#
#                      AEWIHOAKZ_V0  RWWIHOA_MWT0  AEDAHO_T9_V2
# dateTime
# 2019-03-20 14:00:00     45.592339     89.399347     80.655537
# 2019-03-20 14:01:00     44.759943     89.539277     81.089756
# 2019-03-20 14:02:00     45.274554     89.598665     80.335200
# 2019-03-20 14:03:00     45.078444     89.410738     75.924448
# 2019-03-20 14:04:00     42.677696     89.359484     73.998452

# %%
# dataset=np.array(multivariate_data_mean)
dataset=np.array(df_normalized)

NumberOfElements=int(len(dataset)*0.85)
print('Number of Elements for training: ',NumberOfElements)
print('dataset length: ',len(dataset))

train_input=dataset[0:NumberOfElements,0:-1]
print('train_input shape: ',train_input.shape)
train_output=dataset[0:NumberOfElements,-1]
print('train_output shape: ',train_output.shape)

test_input=dataset[NumberOfElements:len(dataset),0:-1]
print('test_input shape: ',test_input.shape)
test_output=dataset[NumberOfElements:len(dataset),-1]
print('test_output shape: ',test_output.shape)

# print('train data size: ',train_data.shape,'\ntest data size: ',test_data.shape)
# Out:
# Number of Elements for training:  16575
# dataset length:  19500
# train_input shape:  (16575, 6)
# train_output shape:  (16575,)
# test_input shape:  (2925, 6)
# test_output shape:  (2925,)

# %% [markdown]
# # How to apply seleted feature in the  machine learning model?? Just do the selection and create a new dataframe with the selected feature and then fed it to the machine learning model.

# %%
df_normalized.head()
# Out:
#                      AEDATZ_HO_V0  AEWIHO_T9AV2  AEWIHOAVABV2  RWWIHOA_HWT0  \
# dateTime
# 2019-03-20 14:00:00      0.793915      0.538414      0.909715      0.930334
# 2019-03-20 14:01:00      0.811504      0.608305      0.911054      0.931562
# 2019-03-20 14:02:00      0.762679      0.625388      0.912085      0.933760
# 2019-03-20 14:03:00      0.715297      0.624726      0.909311      0.931483
# 2019-03-20 14:04:00      0.696728      0.595224      0.909825      0.931371
#
#                      AEWIHOAKZ_V0  RWWIHOA_MWT0  AEDAHO_T9_V2
# dateTime
# 2019-03-20 14:00:00      0.493862      0.887801      0.695416
# 2019-03-20 14:01:00      0.484790      0.889629      0.702452
# 2019-03-20 14:02:00      0.490399      0.890405      0.690225
# 2019-03-20 14:03:00      0.488261      0.887949      0.618750
# 2019-03-20 14:04:00      0.462096      0.887280      0.587540

# %% [markdown]
# # below try to make dataset for feature selection. directly make from panda dataframe.

# %%
train_feature=multivariate_data.iloc[:,:-1]
target_feature=multivariate_data.iloc[:,-1]
a=pd.DataFrame(target_feature)
# target=pd.DataFrame(train_output,index=multivariate_data.index,columns=multivariate_column_label[-1])

# %%
print(type(train_feature))
print(type(target_feature))
print(type(a))
# print(train_feature.head())
# print(target_feature.head())
print(a.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
#                      AEDAHO_T9_V2
# dateTime
# 2019-03-20 14:00:00     80.655537
# 2019-03-20 14:01:00     81.089756
# 2019-03-20 14:02:00     80.335200
# 2019-03-20 14:03:00     75.924448
# 2019-03-20 14:04:00     73.998452

# %%
# train_feature=train_feature.astype(float)
# target_feature=target_feature.astype(float)

# %% [markdown]
# # below trying to do the feature selection but problem occurs with the unknown label type of array which is pointing to the targetted variable.

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=2)
fit = bestfeatures.fit(train_feature,a['AEDAHO_T9_V2'])
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(train_feature.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(4,'Score'))  #print 10 best features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-260678af9e66> in <module>
#       4 #apply SelectKBest class to extract top 10 best features
#       5 bestfeatures = SelectKBest(score_func=chi2, k=2)
# ----> 6 fit = bestfeatures.fit(train_feature,a['AEDAHO_T9_V2'])
#       7 dfscores = pd.DataFrame(fit.scores_)
#       8 dfcolumns = pd.DataFrame(train_feature.columns)
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# --> 349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#     351             self.scores_, self.pvalues_ = score_func_ret
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in chi2(X, y)
#     216         raise ValueError("Input X must be non-negative.")
#     217
# --> 218     Y = LabelBinarizer().fit_transform(y)
#     219     if Y.shape[1] == 1:
#     220         Y = np.append(1 - Y, Y, axis=1)
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit_transform(self, y)
#     434             Shape will be [n_samples, 1] for binary problems.
#     435         """
# --> 436         return self.fit(y).transform(y)
#     437
#     438     def transform(self, y):
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit(self, y)
#     411
#     412         self.sparse_input_ = sp.issparse(y)
# --> 413         self.classes_ = unique_labels(y)
#     414         return self
#     415
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#      94     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#      95     if not _unique_labels:
# ---> 96         raise ValueError("Unknown label type: %s" % repr(ys))
#      97
#      98     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([80.65553691, 81.08975577, 80.33520029, ..., 42.343193  ,
#        42.48031501, 42.30518655]),)

# %% [markdown]
# # Problem also here

# %%
# Import the necessary libraries first
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# Feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(train_feature,a)

# Summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)

features = fit.transform(train_feature)
# Summarize selected features
# print(features[0:5,:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-8e582c4bfbf2> in <module>
#       5 # Feature extraction
#       6 test = SelectKBest(score_func=chi2, k=4)
# ----> 7 fit = test.fit(train_feature,a)
#       8
#       9 # Summarize scores
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# --> 349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#     351             self.scores_, self.pvalues_ = score_func_ret
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in chi2(X, y)
#     216         raise ValueError("Input X must be non-negative.")
#     217
# --> 218     Y = LabelBinarizer().fit_transform(y)
#     219     if Y.shape[1] == 1:
#     220         Y = np.append(1 - Y, Y, axis=1)
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit_transform(self, y)
#     434             Shape will be [n_samples, 1] for binary problems.
#     435         """
# --> 436         return self.fit(y).transform(y)
#     437
#     438     def transform(self, y):
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit(self, y)
#     411
#     412         self.sparse_input_ = sp.issparse(y)
# --> 413         self.classes_ = unique_labels(y)
#     414         return self
#     415
#
# ~/anaconda3/envs/venv/lib/python3.6/site-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#      94     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#      95     if not _unique_labels:
# ---> 96         raise ValueError("Unknown label type: %s" % repr(ys))
#      97
#      98     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([[80.65553691],
#        [81.08975577],
#        [80.33520029],
#        ...,
#        [42.343193  ],
#        [42.48031501],
#        [42.30518655]]),)

# %% [markdown]
# # correlation. followed this link for doing https://towardsdatascience.com/feature-selection-with-pandas-e3690ad8504b

# %%
#Using Pearson Correlation
import seaborn as sns
plt.figure(figsize=(12,10))
cor = multivariate_data_mean.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor["AEDAHO_T9_V2"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# AEDATZ_HO_V0    0.654874
# AEWIHO_T9AV2    0.794874
# AEDAHO_T9_V2    1.000000
# Name: AEDAHO_T9_V2, dtype: float64

# %%
import statsmodels.api as sm
#Adding constant column of ones, mandatory for sm.OLS model
X_1 = sm.add_constant(train_feature)
#Fitting sm.OLS model
model = sm.OLS(a,X_1).fit()
model.pvalues
# Out:
# const            1.718867e-22
# AEDATZ_HO_V0     0.000000e+00
# AEWIHO_T9AV2     0.000000e+00
# AEWIHOAVABV2     7.110610e-02
# RWWIHOA_HWT0    4.776539e-203
# AEWIHOAKZ_V0     4.036193e-88
# RWWIHOA_MWT0    1.014904e-231
# dtype: float64

# %%
#Backward Elimination
cols = list(train_feature.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = train_feature[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(a,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['AEDATZ_HO_V0', 'AEWIHO_T9AV2', 'RWWIHOA_HWT0', 'AEWIHOAKZ_V0', 'RWWIHOA_MWT0']
