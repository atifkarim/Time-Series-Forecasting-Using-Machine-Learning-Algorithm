# %%
import numpy as np
import pandas as pd
# Creating a 2 dimensional numpy array
data= np.array([[ 5.8,80,10,70], [ 0,2.2,10,9],[ -6.0,0,10,10],[ 6.0,2.2,10,0],[ 6.0,2.2,10,20],[ -9,24,10,0]
               ,[ 6.0,2.2,10,50],[ 65,2,10,0]])

# %%
data
# Out:
# array([[ 5.8, 80. , 10. , 70. ],
#        [ 0. ,  2.2, 10. ,  9. ],
#        [-6. ,  0. , 10. , 10. ],
#        [ 6. ,  2.2, 10. ,  0. ],
#        [ 6. ,  2.2, 10. , 20. ],
#        [-9. , 24. , 10. ,  0. ],
#        [ 6. ,  2.2, 10. , 50. ],
#        [65. ,  2. , 10. ,  0. ]])

# %%
row=[]
row=np.array(row)
for i, index in enumerate(data):
#     print(i)
    row=np.append(row,i)
print(row.shape)
row = np.reshape(row, (-1, 1))
print(row.shape)
test_data=pd.DataFrame(data=data[0:,0:],    # values
             index=row[0:,0],    # 1st column as index
             columns=data[0,0:])  # 1st row as the column names
print(type(test_data))
# print(test_data)
test_data.columns = ['a', 'b','c','d']
print(test_data)
# Out:
# (8,)
# (8, 1)
# <class 'pandas.core.frame.DataFrame'>
#         a     b     c     d
# 0.0   5.8  80.0  10.0  70.0
# 1.0   0.0   2.2  10.0   9.0
# 2.0  -6.0   0.0  10.0  10.0
# 3.0   6.0   2.2  10.0   0.0
# 4.0   6.0   2.2  10.0  20.0
# 5.0  -9.0  24.0  10.0   0.0
# 6.0   6.0   2.2  10.0  50.0
# 7.0  65.0   2.0  10.0   0.0

# %%
new_data = test_data.assign(cMINUSd = test_data.c + test_data.d,
          aPLUSb = test_data.a - test_data.b)

# %%
row='ROW'
new_row=[]
new_row=np.array(new_row)
for i in range(0,new_data.shape[0]):
    row_1=str(row)+'_'+str(i)
    new_row = np.append(new_row,row_1)

print(new_row)
# Out:
# ['ROW_0' 'ROW_1' 'ROW_2' 'ROW_3' 'ROW_4' 'ROW_5' 'ROW_6' 'ROW_7']

# %%
index_list=[]
index_list=np.array(index_list)
for i in range (0, new_data.shape[0]):
    index_1 = new_data.index[i]
    index_list = np.append(index_list,index_1)

print(index_list)
# Out:
# [0. 1. 2. 3. 4. 5. 6. 7.]

# %%
for i in range (0, new_data.shape[0]):
    new_data_new_row = new_data.rename(index={index_list[i]: new_row[i]})

# %%
drop_index=[]
drop_index=np.array(drop_index)
print(type(drop_index))
for index, value in test_data.iterrows():
#     print('value: ', value)
    for i , v in enumerate(value):
#         print('i: ',i)
#         print('v: ',v)
        if i == 3 and v == 0.0:
            print('index: ',index)
            
            drop_index=np.append(drop_index,index)

print('drop_index: ',drop_index)
# Out:
# <class 'numpy.ndarray'>
# index:  3.0
# index:  5.0
# index:  7.0
# drop_index:  [3. 5. 7.]

# %%
modify_frame=test_data.drop(drop_index,axis=0)

# %%
modify_frame
# Out:
#        a     b     c     d
# 0.0  5.8  80.0  10.0  70.0
# 1.0  0.0   2.2  10.0   9.0
# 2.0 -6.0   0.0  10.0  10.0
# 4.0  6.0   2.2  10.0  20.0
# 6.0  6.0   2.2  10.0  50.0

# %%
modify_frame.shape[1]
# Out:
# 4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams

# %%
ax = modify_frame.plot(subplots=True, layout=(modify_frame.shape[1],1))
plt.rcParams['figure.figsize'] =(20,40)
# plt.tight_layout()
plt.savefig('test.png')
# ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.show()
